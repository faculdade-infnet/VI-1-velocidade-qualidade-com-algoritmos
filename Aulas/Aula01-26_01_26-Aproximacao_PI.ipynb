# %% [markdown]
# # pi - Gregory-Leibiz
# - Calcula Quantos termos da série são necessários para obtermos os valores dentro do Array
# - Apróximação do número PI

# %%
pi = 0         # variavel
sinal = -1     # A cada passo multiplico por -1
i = 0          # Contador de passos
indice = 0     # contador de item do array
L = [3.14 , 3.141, 3.1415, 3.14159] # array com possíveis respostas
comp = len(L)  # comprimenot do array de respostas

while (indice < comp):
    sinal = (-1)*sinal             # obrigatório pois a série exige
    pi = pi + 4 * sinal/(2*i + 1)  # pi(sempre o último valor)/(gera números ímpares em sequência)
    i = i + 1

    # round pois é um float com casas decimais talvez infinitas
    # verifica se o numnero encontra = igual ao array
    if (round(pi, indice + 2)) == L[indice]:
        print(L[indice], "encontrado com ", i, "passos.")
        # se for igual ao indice do array aumenta o valor do indice em +1
        indice = indice + 1
# Out:
# 3.14 encontrado com  152 passos.
# 3.141 encontrado com  916 passos.
# 3.1415 encontrado com  7010 passos.
# 3.14159 encontrado com  130658 passos.

# %% [markdown]
# #
# ![pi Gregory-Leibiz1.png](data:image/png;base64,...)
